# %%
import pandas as pd
import numpy as np

# %%
dohmh_df = pd.read_csv("./data_csvs/DOHMH_New_York_City_Restaurant_Inspection_Results_20231202.csv")
dohmh_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209789 entries, 0 to 209788
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   CAMIS                  209789 non-null  int64
#  1   DBA                    209165 non-null  object
#  2   BORO                   209789 non-null  object
#  3   BUILDING               209481 non-null  object
#  4   STREET                 209783 non-null  object
#  5   ZIPCODE                207093 non-null  float64
#  6   PHONE                  209781 non-null  object
#  7   CUISINE DESCRIPTION    207365 non-null  object
#  8   INSPECTION DATE        209789 non-null  object
#  9   ACTION                 207365 non-null  object
#  10  VIOLATION CODE         206208 non-null  object
#  11  VIOLATION DESCRIPTION  206208 non-null  object
#  12  CRITICAL FLAG          209789 non-null  object
#  13  SCORE                  199793 non-null  float64
# ...

# %%
dohmh_df[dohmh_df['CAMIS']==41658324]
# Out:
#            CAMIS                 DBA    BORO BUILDING          STREET  \
# 14420   41658324  MI CASA RESTAURANT  Queens    11620  JAMAICA AVENUE
# 25856   41658324  MI CASA RESTAURANT  Queens    11620  JAMAICA AVENUE
# 27579   41658324  MI CASA RESTAURANT  Queens    11620  JAMAICA AVENUE
# 31099   41658324  MI CASA RESTAURANT  Queens    11620  JAMAICA AVENUE
# 35037   41658324  MI CASA RESTAURANT  Queens    11620  JAMAICA AVENUE
# 36912   41658324  MI CASA RESTAURANT  Queens    11620  JAMAICA AVENUE
# 37836   41658324  MI CASA RESTAURANT  Queens    11620  JAMAICA AVENUE
# 40248   41658324  MI CASA RESTAURANT  Queens    11620  JAMAICA AVENUE
# 45843   41658324  MI CASA RESTAURANT  Queens    11620  JAMAICA AVENUE
# 48800   41658324  MI CASA RESTAURANT  Queens    11620  JAMAICA AVENUE
# 51256   41658324  MI CASA RESTAURANT  Queens    11620  JAMAICA AVENUE
# 53385   41658324  MI CASA RESTAURANT  Queens    11620  JAMAICA AVENUE
# ...

# %%
dohmh_df_cleaned = pd.read_csv('cleaned_dohmh.csv')

# %%
dohmh_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209789 entries, 0 to 209788
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   CAMIS                  209789 non-null  int64
#  1   DBA                    209165 non-null  object
#  2   BORO                   209789 non-null  object
#  3   BUILDING               209481 non-null  object
#  4   STREET                 209783 non-null  object
#  5   ZIPCODE                207093 non-null  float64
#  6   PHONE                  209781 non-null  object
#  7   CUISINE DESCRIPTION    207365 non-null  object
#  8   INSPECTION DATE        209789 non-null  object
#  9   ACTION                 207365 non-null  object
#  10  VIOLATION CODE         206208 non-null  object
#  11  VIOLATION DESCRIPTION  206208 non-null  object
#  12  CRITICAL FLAG          209789 non-null  object
#  13  SCORE                  199793 non-null  float64
# ...

# %%
dohmh_df_cleaned[dohmh_df_cleaned['CAMIS']==41658324]
# Out:
#            CAMIS                 DBA    BORO BUILDING          STREET  \
# 14415   41658324  Mi Casa Restaurant  Queens    11620  Jamaica Avenue
# 25851   41658324  Mi Casa Restaurant  Queens    11620  Jamaica Avenue
# 27574   41658324  Mi Casa Restaurant  Queens    11620  Jamaica Avenue
# 31094   41658324  Mi Casa Restaurant  Queens    11620  Jamaica Avenue
# 35032   41658324  Mi Casa Restaurant  Queens    11620  Jamaica Avenue
# 36907   41658324  Mi Casa Restaurant  Queens    11620  Jamaica Avenue
# 37831   41658324  Mi Casa Restaurant  Queens    11620  Jamaica Avenue
# 40243   41658324  Mi Casa Restaurant  Queens    11620  Jamaica Avenue
# 45837   41658324  Mi Casa Restaurant  Queens    11620  Jamaica Avenue
# 48794   41658324  Mi Casa Restaurant  Queens    11620  Jamaica Avenue
# 51250   41658324  Mi Casa Restaurant  Queens    11620  Jamaica Avenue
# 53379   41658324  Mi Casa Restaurant  Queens    11620  Jamaica Avenue
# ...
