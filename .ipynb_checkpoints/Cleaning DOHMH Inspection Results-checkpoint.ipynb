# %%
import pandas as pd
import numpy as np
import html
import matplotlib as plt
pd.set_option('display.max_columns', None)

# %%
dohmh_df = pd.read_csv("./data_csvs/DOHMH_New_York_City_Restaurant_Inspection_Results_20231202.csv")
dohmh_df
# Out:
#            CAMIS                            DBA       BORO BUILDING  \
# 0       50106271                     SOUR MOUSE  Manhattan      110
# 1       50117820  MODELLO BAR - BARCLAYS CENTER   Brooklyn      620
# 2       50141790                            NaN  Manhattan       30
# 3       50134862         FINE AND RAW CHOCOLATE   Brooklyn       70
# 4       50127238           THE DELUXE PARTY KTV     Queens     3420
# ...          ...                            ...        ...      ...
# 209784  50129459                      BLUEBERRY   Brooklyn     1849
# 209785  41444866                  PIES-N-THIGHS   Brooklyn      166
# 209786  50123805             QK Restaurant Inc.     Queens     4626
# 209787  50056510        GINBO'S HAMBURGER HOUSE      Bronx      118
# 209788  41112524           ADRIENNE'S PIZZA BAR  Manhattan       54
#
#                      STREET  ZIPCODE       PHONE       CUISINE DESCRIPTION  \
# 0           DELANCEY STREET  10002.0  6462567220                       NaN
# 1           ATLANTIC AVENUE  11217.0  9174174384                       NaN
# 2          EAST   20 STREET  10003.0  9176670036                       NaN
# 3              SCOTT AVENUE  11237.0  6462440734                       NaN
# 4                 LINDEN PL  11354.0  9172957843                       NaN
# ...                     ...      ...         ...                       ...
# 209784  CONEY ISLAND AVENUE  11230.0  3473719836  Bakery Products/Desserts
# 209785    SOUTH    4 STREET  11211.0  3475296090                  American
# 209786         KISSENA BLVD  11355.0  7189990806                   Chinese
# 209787     EAST  170 STREET  10452.0  3479634644                Hamburgers
# 209788         STONE STREET  10004.0  2122483838                   Italian
#
#        INSPECTION DATE                                           ACTION  \
# 0           01/01/1900                                              NaN
# 1           01/01/1900                                              NaN
# 2           01/01/1900                                              NaN
# 3           01/01/1900                                              NaN
# 4           01/01/1900                                              NaN
# ...                ...                                              ...
# 209784      08/03/2023  Violations were cited in the following area(s).
# 209785      08/09/2023  Violations were cited in the following area(s).
# 209786      08/01/2022  Violations were cited in the following area(s).
# 209787      09/28/2022  Violations were cited in the following area(s).
# 209788      03/10/2022  Violations were cited in the following area(s).
#
#        VIOLATION CODE                              VIOLATION DESCRIPTION  \
# 0                 NaN                                                NaN
# 1                 NaN                                                NaN
# 2                 NaN                                                NaN
# 3                 NaN                                                NaN
# 4                 NaN                                                NaN
# ...               ...                                                ...
# 209784            02A  Time/Temperature Control for Safety (TCS) food...
# 209785            04N  Filth flies or food/refuse/sewage associated w...
# 209786            06D  Food contact surface not properly washed, rins...
# 209787            08A  Establishment is not free of harborage or cond...
# 209788            04L  Evidence of mice or live mice present in facil...
#
#          CRITICAL FLAG  SCORE GRADE  GRADE DATE RECORD DATE  \
# 0       Not Applicable    NaN   NaN         NaN  12/01/2023
# 1       Not Applicable    NaN   NaN         NaN  12/01/2023
# 2       Not Applicable    NaN   NaN         NaN  12/01/2023
# 3       Not Applicable    NaN   NaN         NaN  12/01/2023
# 4       Not Applicable    NaN   NaN         NaN  12/01/2023
# ...                ...    ...   ...         ...         ...
# 209784        Critical   50.0   NaN         NaN  12/01/2023
# 209785        Critical   18.0     B  08/09/2023  12/01/2023
# 209786        Critical   29.0     C  08/01/2022  12/01/2023
# 209787    Not Critical   21.0   NaN         NaN  12/01/2023
# 209788        Critical   21.0   NaN         NaN  12/01/2023
#
#                                  INSPECTION TYPE   Latitude  Longitude  \
# 0                                            NaN  40.718640 -73.988481
# 1                                            NaN  40.683447 -73.975691
# 2                                            NaN  40.738929 -73.989221
# 3                                            NaN  40.709853 -73.922706
# 4                                            NaN  40.766275 -73.831338
# ...                                          ...        ...        ...
# 209784     Cycle Inspection / Initial Inspection  40.611980 -73.962744
# 209785          Cycle Inspection / Re-inspection  40.711289 -73.961300
# 209786  Pre-permit (Operational) / Re-inspection  40.750040 -73.818520
# 209787  Cycle Inspection / Compliance Inspection  40.839304 -73.915334
# 209788     Cycle Inspection / Initial Inspection  40.704403 -74.010211
#
#         Community Board  Council District  Census Tract        BIN  \
# 0                 103.0               1.0        1800.0  1087565.0
# 1                 302.0              35.0       12902.0  3398156.0
# 2                 105.0               2.0        5200.0  1016181.0
# 3                 301.0              34.0       44900.0  3070597.0
# 4                 407.0              20.0       86900.0  4112007.0
# ...                 ...               ...           ...        ...
# 209784            314.0              48.0       54200.0  3181708.0
# 209785            301.0              34.0       52300.0  3063458.0
# 209786            407.0              20.0       84500.0  4314742.0
# 209787            204.0              16.0       22102.0  2008084.0
# 209788            101.0               1.0         900.0  1088620.0
#
#                  BBL   NTA  Location Point1
# 0       1.004100e+09  MN27              NaN
# 1       3.011180e+09  BK37              NaN
# 2       1.008480e+09  MN13              NaN
# 3       3.029900e+09  BK90              NaN
# 4       4.049500e+09  QN22              NaN
# ...              ...   ...              ...
# 209784  3.067580e+09  BK43              NaN
# 209785  3.024460e+09  BK73              NaN
# 209786  4.051490e+09  QN22              NaN
# 209787  2.028420e+09  BX63              NaN
# 209788  1.000298e+09  MN25              NaN
#
# [209789 rows x 27 columns]

# %%
dohmh_df = dohmh_df.drop_duplicates()
dohmh_df
# Out:
#            CAMIS                            DBA       BORO BUILDING  \
# 0       50106271                     SOUR MOUSE  Manhattan      110
# 1       50117820  MODELLO BAR - BARCLAYS CENTER   Brooklyn      620
# 2       50141790                            NaN  Manhattan       30
# 3       50134862         FINE AND RAW CHOCOLATE   Brooklyn       70
# 4       50127238           THE DELUXE PARTY KTV     Queens     3420
# ...          ...                            ...        ...      ...
# 209784  50129459                      BLUEBERRY   Brooklyn     1849
# 209785  41444866                  PIES-N-THIGHS   Brooklyn      166
# 209786  50123805             QK Restaurant Inc.     Queens     4626
# 209787  50056510        GINBO'S HAMBURGER HOUSE      Bronx      118
# 209788  41112524           ADRIENNE'S PIZZA BAR  Manhattan       54
#
#                      STREET  ZIPCODE       PHONE       CUISINE DESCRIPTION  \
# 0           DELANCEY STREET  10002.0  6462567220                       NaN
# 1           ATLANTIC AVENUE  11217.0  9174174384                       NaN
# 2          EAST   20 STREET  10003.0  9176670036                       NaN
# 3              SCOTT AVENUE  11237.0  6462440734                       NaN
# 4                 LINDEN PL  11354.0  9172957843                       NaN
# ...                     ...      ...         ...                       ...
# 209784  CONEY ISLAND AVENUE  11230.0  3473719836  Bakery Products/Desserts
# 209785    SOUTH    4 STREET  11211.0  3475296090                  American
# 209786         KISSENA BLVD  11355.0  7189990806                   Chinese
# 209787     EAST  170 STREET  10452.0  3479634644                Hamburgers
# 209788         STONE STREET  10004.0  2122483838                   Italian
#
#        INSPECTION DATE                                           ACTION  \
# 0           01/01/1900                                              NaN
# 1           01/01/1900                                              NaN
# 2           01/01/1900                                              NaN
# 3           01/01/1900                                              NaN
# 4           01/01/1900                                              NaN
# ...                ...                                              ...
# 209784      08/03/2023  Violations were cited in the following area(s).
# 209785      08/09/2023  Violations were cited in the following area(s).
# 209786      08/01/2022  Violations were cited in the following area(s).
# 209787      09/28/2022  Violations were cited in the following area(s).
# 209788      03/10/2022  Violations were cited in the following area(s).
#
#        VIOLATION CODE                              VIOLATION DESCRIPTION  \
# 0                 NaN                                                NaN
# 1                 NaN                                                NaN
# 2                 NaN                                                NaN
# 3                 NaN                                                NaN
# 4                 NaN                                                NaN
# ...               ...                                                ...
# 209784            02A  Time/Temperature Control for Safety (TCS) food...
# 209785            04N  Filth flies or food/refuse/sewage associated w...
# 209786            06D  Food contact surface not properly washed, rins...
# 209787            08A  Establishment is not free of harborage or cond...
# 209788            04L  Evidence of mice or live mice present in facil...
#
#          CRITICAL FLAG  SCORE GRADE  GRADE DATE RECORD DATE  \
# 0       Not Applicable    NaN   NaN         NaN  12/01/2023
# 1       Not Applicable    NaN   NaN         NaN  12/01/2023
# 2       Not Applicable    NaN   NaN         NaN  12/01/2023
# 3       Not Applicable    NaN   NaN         NaN  12/01/2023
# 4       Not Applicable    NaN   NaN         NaN  12/01/2023
# ...                ...    ...   ...         ...         ...
# 209784        Critical   50.0   NaN         NaN  12/01/2023
# 209785        Critical   18.0     B  08/09/2023  12/01/2023
# 209786        Critical   29.0     C  08/01/2022  12/01/2023
# 209787    Not Critical   21.0   NaN         NaN  12/01/2023
# 209788        Critical   21.0   NaN         NaN  12/01/2023
#
#                                  INSPECTION TYPE   Latitude  Longitude  \
# 0                                            NaN  40.718640 -73.988481
# 1                                            NaN  40.683447 -73.975691
# 2                                            NaN  40.738929 -73.989221
# 3                                            NaN  40.709853 -73.922706
# 4                                            NaN  40.766275 -73.831338
# ...                                          ...        ...        ...
# 209784     Cycle Inspection / Initial Inspection  40.611980 -73.962744
# 209785          Cycle Inspection / Re-inspection  40.711289 -73.961300
# 209786  Pre-permit (Operational) / Re-inspection  40.750040 -73.818520
# 209787  Cycle Inspection / Compliance Inspection  40.839304 -73.915334
# 209788     Cycle Inspection / Initial Inspection  40.704403 -74.010211
#
#         Community Board  Council District  Census Tract        BIN  \
# 0                 103.0               1.0        1800.0  1087565.0
# 1                 302.0              35.0       12902.0  3398156.0
# 2                 105.0               2.0        5200.0  1016181.0
# 3                 301.0              34.0       44900.0  3070597.0
# 4                 407.0              20.0       86900.0  4112007.0
# ...                 ...               ...           ...        ...
# 209784            314.0              48.0       54200.0  3181708.0
# 209785            301.0              34.0       52300.0  3063458.0
# 209786            407.0              20.0       84500.0  4314742.0
# 209787            204.0              16.0       22102.0  2008084.0
# 209788            101.0               1.0         900.0  1088620.0
#
#                  BBL   NTA  Location Point1
# 0       1.004100e+09  MN27              NaN
# 1       3.011180e+09  BK37              NaN
# 2       1.008480e+09  MN13              NaN
# 3       3.029900e+09  BK90              NaN
# 4       4.049500e+09  QN22              NaN
# ...              ...   ...              ...
# 209784  3.067580e+09  BK43              NaN
# 209785  3.024460e+09  BK73              NaN
# 209786  4.051490e+09  QN22              NaN
# 209787  2.028420e+09  BX63              NaN
# 209788  1.000298e+09  MN25              NaN
#
# [209783 rows x 27 columns]

# %%
dohmh_df['Location Point1'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 dohmh_df['Location Point1'].value_counts()
#
# NameError: name 'dohmh_df' is not defined

# %%
dohmh_df=dohmh_df[dohmh_df['INSPECTION DATE']!='01/01/1900']

# %%
dohmh_df['INSPECTION DATE'].value_counts()
# Out:
# 04/13/2023    597
# 03/16/2023    585
# 02/16/2023    564
# 05/12/2022    551
# 04/26/2023    545
#              ...
# 02/02/2017      1
# 06/28/2021      1
# 05/14/2021      1
# 02/05/2021      1
# 05/28/2022      1
# Name: INSPECTION DATE, Length: 1674, dtype: int64

# %%
dohmh_df['ZIPCODE'] = dohmh_df['ZIPCODE'].astype(str).str.replace(r'\.\d+', '', regex=True)
# Out:
# C:\Users\Prateek\AppData\Local\Temp\ipykernel_31896\747011896.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dohmh_df['ZIPCODE'] = dohmh_df['ZIPCODE'].astype(str).str.replace(r'\.\d+', '', regex=True)

# %%
dohmh_df
# Out:
#            CAMIS                      DBA       BORO BUILDING  \
# 9       50067297       GERBASI RESTAURANT      Bronx     2389
# 11      50034232          RELISH CATERERS      Bronx     2501
# 14      50064240             DAXI SICHUAN     Queens   136-20
# 15      50105603        LE PAIN QUOTIDIEN  Manhattan       81
# 25      50069583                 PHO BEST     Queens     4235
# ...          ...                      ...        ...      ...
# 209784  50129459                BLUEBERRY   Brooklyn     1849
# 209785  41444866            PIES-N-THIGHS   Brooklyn      166
# 209786  50123805       QK Restaurant Inc.     Queens     4626
# 209787  50056510  GINBO'S HAMBURGER HOUSE      Bronx      118
# 209788  41112524     ADRIENNE'S PIZZA BAR  Manhattan       54
#
#                      STREET ZIPCODE       PHONE       CUISINE DESCRIPTION  \
# 9             ARTHUR AVENUE   10458  7182205735                   Italian
# 11                 3 AVENUE   10451  2122281672                  American
# 14         ROOSEVELT AVENUE   11354  9175631983                   Chinese
# 15            WEST BROADWAY   10007  6468639168                    French
# 25                  MAIN ST   11355  9173618878           Southeast Asian
# ...                     ...     ...         ...                       ...
# 209784  CONEY ISLAND AVENUE   11230  3473719836  Bakery Products/Desserts
# 209785    SOUTH    4 STREET   11211  3475296090                  American
# 209786         KISSENA BLVD   11355  7189990806                   Chinese
# 209787     EAST  170 STREET   10452  3479634644                Hamburgers
# 209788         STONE STREET   10004  2122483838                   Italian
#
#        INSPECTION DATE                                             ACTION  \
# 9           09/12/2021  No violations were recorded at the time of thi...
# 11          09/25/2021  No violations were recorded at the time of thi...
# 14          09/21/2022    Violations were cited in the following area(s).
# 15          11/25/2022  No violations were recorded at the time of thi...
# 25          05/09/2022    Violations were cited in the following area(s).
# ...                ...                                                ...
# 209784      08/03/2023    Violations were cited in the following area(s).
# 209785      08/09/2023    Violations were cited in the following area(s).
# 209786      08/01/2022    Violations were cited in the following area(s).
# 209787      09/28/2022    Violations were cited in the following area(s).
# 209788      03/10/2022    Violations were cited in the following area(s).
#
#        VIOLATION CODE                              VIOLATION DESCRIPTION  \
# 9                 NaN                                                NaN
# 11                NaN                                                NaN
# 14                09B                        Thawing procedure improper.
# 15                NaN                                                NaN
# 25                02B         Hot food item not held at or above 140º F.
# ...               ...                                                ...
# 209784            02A  Time/Temperature Control for Safety (TCS) food...
# 209785            04N  Filth flies or food/refuse/sewage associated w...
# 209786            06D  Food contact surface not properly washed, rins...
# 209787            08A  Establishment is not free of harborage or cond...
# 209788            04L  Evidence of mice or live mice present in facil...
#
#          CRITICAL FLAG  SCORE GRADE  GRADE DATE RECORD DATE  \
# 9       Not Applicable    0.0   NaN         NaN  12/01/2023
# 11      Not Applicable    0.0   NaN         NaN  12/01/2023
# 14        Not Critical   13.0     A  09/21/2022  12/01/2023
# 15      Not Applicable    NaN   NaN         NaN  12/01/2023
# 25            Critical   30.0   NaN         NaN  12/01/2023
# ...                ...    ...   ...         ...         ...
# 209784        Critical   50.0   NaN         NaN  12/01/2023
# 209785        Critical   18.0     B  08/09/2023  12/01/2023
# 209786        Critical   29.0     C  08/01/2022  12/01/2023
# 209787    Not Critical   21.0   NaN         NaN  12/01/2023
# 209788        Critical   21.0   NaN         NaN  12/01/2023
#
#                                      INSPECTION TYPE   Latitude  Longitude  \
# 9       Inter-Agency Task Force / Initial Inspection  40.855290 -73.887797
# 11      Inter-Agency Task Force / Initial Inspection  40.810202 -73.928401
# 14             Cycle Inspection / Initial Inspection  40.759778 -73.829235
# 15      Administrative Miscellaneous / Re-inspection  40.715083 -74.009567
# 25             Cycle Inspection / Initial Inspection  40.754418 -73.827881
# ...                                              ...        ...        ...
# 209784         Cycle Inspection / Initial Inspection  40.611980 -73.962744
# 209785              Cycle Inspection / Re-inspection  40.711289 -73.961300
# 209786      Pre-permit (Operational) / Re-inspection  40.750040 -73.818520
# 209787      Cycle Inspection / Compliance Inspection  40.839304 -73.915334
# 209788         Cycle Inspection / Initial Inspection  40.704403 -74.010211
#
#         Community Board  Council District  Census Tract        BIN  \
# 9                 206.0              15.0       39100.0  2011897.0
# 11                201.0               8.0        5100.0  2000795.0
# 14                407.0              20.0       85300.0  4113546.0
# 15                101.0               1.0        2100.0  1001480.0
# 25                407.0              20.0       85300.0  4573539.0
# ...                 ...               ...           ...        ...
# 209784            314.0              48.0       54200.0  3181708.0
# 209785            301.0              34.0       52300.0  3063458.0
# 209786            407.0              20.0       84500.0  4314742.0
# 209787            204.0              16.0       22102.0  2008084.0
# 209788            101.0               1.0         900.0  1088620.0
#
#                  BBL   NTA  Location Point1
# 9       2.030650e+09  BX06              NaN
# 11      2.023200e+09  BX39              NaN
# 14      4.050190e+09  QN22              NaN
# 15      1.001368e+09  MN24              NaN
# 25      4.051358e+09  QN22              NaN
# ...              ...   ...              ...
# 209784  3.067580e+09  BK43              NaN
# 209785  3.024460e+09  BK73              NaN
# 209786  4.051490e+09  QN22              NaN
# 209787  2.028420e+09  BX63              NaN
# 209788  1.000298e+09  MN25              NaN
#
# [207359 rows x 27 columns]

# %%
def capitalize_column(dataframe, column):
    dataframe[column]=dataframe[column].str.title()
    return dataframe

# %%
dohmh_df = capitalize_column(dohmh_df,'STREET')
dohmh_df = capitalize_column(dohmh_df,'DBA')
# Out:
# C:\Users\Prateek\AppData\Local\Temp\ipykernel_31896\311252202.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[column]=dataframe[column].str.title()

# %%
dohmh_df
# Out:
#            CAMIS                      DBA       BORO BUILDING  \
# 9       50067297       Gerbasi Restaurant      Bronx     2389
# 11      50034232          Relish Caterers      Bronx     2501
# 14      50064240             Daxi Sichuan     Queens   136-20
# 15      50105603        Le Pain Quotidien  Manhattan       81
# 25      50069583                 Pho Best     Queens     4235
# ...          ...                      ...        ...      ...
# 209784  50129459                Blueberry   Brooklyn     1849
# 209785  41444866            Pies-N-Thighs   Brooklyn      166
# 209786  50123805       Qk Restaurant Inc.     Queens     4626
# 209787  50056510  Ginbo'S Hamburger House      Bronx      118
# 209788  41112524     Adrienne'S Pizza Bar  Manhattan       54
#
#                      STREET ZIPCODE       PHONE       CUISINE DESCRIPTION  \
# 9             Arthur Avenue   10458  7182205735                   Italian
# 11                 3 Avenue   10451  2122281672                  American
# 14         Roosevelt Avenue   11354  9175631983                   Chinese
# 15            West Broadway   10007  6468639168                    French
# 25                  Main St   11355  9173618878           Southeast Asian
# ...                     ...     ...         ...                       ...
# 209784  Coney Island Avenue   11230  3473719836  Bakery Products/Desserts
# 209785    South    4 Street   11211  3475296090                  American
# 209786         Kissena Blvd   11355  7189990806                   Chinese
# 209787     East  170 Street   10452  3479634644                Hamburgers
# 209788         Stone Street   10004  2122483838                   Italian
#
#        INSPECTION DATE                                             ACTION  \
# 9           09/12/2021  No violations were recorded at the time of thi...
# 11          09/25/2021  No violations were recorded at the time of thi...
# 14          09/21/2022    Violations were cited in the following area(s).
# 15          11/25/2022  No violations were recorded at the time of thi...
# 25          05/09/2022    Violations were cited in the following area(s).
# ...                ...                                                ...
# 209784      08/03/2023    Violations were cited in the following area(s).
# 209785      08/09/2023    Violations were cited in the following area(s).
# 209786      08/01/2022    Violations were cited in the following area(s).
# 209787      09/28/2022    Violations were cited in the following area(s).
# 209788      03/10/2022    Violations were cited in the following area(s).
#
#        VIOLATION CODE                              VIOLATION DESCRIPTION  \
# 9                 NaN                                                NaN
# 11                NaN                                                NaN
# 14                09B                        Thawing procedure improper.
# 15                NaN                                                NaN
# 25                02B         Hot food item not held at or above 140º F.
# ...               ...                                                ...
# 209784            02A  Time/Temperature Control for Safety (TCS) food...
# 209785            04N  Filth flies or food/refuse/sewage associated w...
# 209786            06D  Food contact surface not properly washed, rins...
# 209787            08A  Establishment is not free of harborage or cond...
# 209788            04L  Evidence of mice or live mice present in facil...
#
#          CRITICAL FLAG  SCORE GRADE  GRADE DATE RECORD DATE  \
# 9       Not Applicable    0.0   NaN         NaN  12/01/2023
# 11      Not Applicable    0.0   NaN         NaN  12/01/2023
# 14        Not Critical   13.0     A  09/21/2022  12/01/2023
# 15      Not Applicable    NaN   NaN         NaN  12/01/2023
# 25            Critical   30.0   NaN         NaN  12/01/2023
# ...                ...    ...   ...         ...         ...
# 209784        Critical   50.0   NaN         NaN  12/01/2023
# 209785        Critical   18.0     B  08/09/2023  12/01/2023
# 209786        Critical   29.0     C  08/01/2022  12/01/2023
# 209787    Not Critical   21.0   NaN         NaN  12/01/2023
# 209788        Critical   21.0   NaN         NaN  12/01/2023
#
#                                      INSPECTION TYPE   Latitude  Longitude  \
# 9       Inter-Agency Task Force / Initial Inspection  40.855290 -73.887797
# 11      Inter-Agency Task Force / Initial Inspection  40.810202 -73.928401
# 14             Cycle Inspection / Initial Inspection  40.759778 -73.829235
# 15      Administrative Miscellaneous / Re-inspection  40.715083 -74.009567
# 25             Cycle Inspection / Initial Inspection  40.754418 -73.827881
# ...                                              ...        ...        ...
# 209784         Cycle Inspection / Initial Inspection  40.611980 -73.962744
# 209785              Cycle Inspection / Re-inspection  40.711289 -73.961300
# 209786      Pre-permit (Operational) / Re-inspection  40.750040 -73.818520
# 209787      Cycle Inspection / Compliance Inspection  40.839304 -73.915334
# 209788         Cycle Inspection / Initial Inspection  40.704403 -74.010211
#
#         Community Board  Council District  Census Tract        BIN  \
# 9                 206.0              15.0       39100.0  2011897.0
# 11                201.0               8.0        5100.0  2000795.0
# 14                407.0              20.0       85300.0  4113546.0
# 15                101.0               1.0        2100.0  1001480.0
# 25                407.0              20.0       85300.0  4573539.0
# ...                 ...               ...           ...        ...
# 209784            314.0              48.0       54200.0  3181708.0
# 209785            301.0              34.0       52300.0  3063458.0
# 209786            407.0              20.0       84500.0  4314742.0
# 209787            204.0              16.0       22102.0  2008084.0
# 209788            101.0               1.0         900.0  1088620.0
#
#                  BBL   NTA  Location Point1
# 9       2.030650e+09  BX06              NaN
# 11      2.023200e+09  BX39              NaN
# 14      4.050190e+09  QN22              NaN
# 15      1.001368e+09  MN24              NaN
# 25      4.051358e+09  QN22              NaN
# ...              ...   ...              ...
# 209784  3.067580e+09  BK43              NaN
# 209785  3.024460e+09  BK73              NaN
# 209786  4.051490e+09  QN22              NaN
# 209787  2.028420e+09  BX63              NaN
# 209788  1.000298e+09  MN25              NaN
#
# [207359 rows x 27 columns]
