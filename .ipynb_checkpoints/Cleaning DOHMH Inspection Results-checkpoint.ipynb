# %%
import pandas as pd
import re
import numpy as np
import html
import matplotlib as plt
pd.set_option('display.max_columns', None)

# %%
dohmh_df = pd.read_csv("./data_csvs/DOHMH_New_York_City_Restaurant_Inspection_Results_20231202.csv")
dohmh_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209789 entries, 0 to 209788
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   CAMIS                  209789 non-null  int64
#  1   DBA                    209165 non-null  object
#  2   BORO                   209789 non-null  object
#  3   BUILDING               209481 non-null  object
#  4   STREET                 209783 non-null  object
#  5   ZIPCODE                207093 non-null  float64
#  6   PHONE                  209781 non-null  object
#  7   CUISINE DESCRIPTION    207365 non-null  object
#  8   INSPECTION DATE        209789 non-null  object
#  9   ACTION                 207365 non-null  object
#  10  VIOLATION CODE         206208 non-null  object
#  11  VIOLATION DESCRIPTION  206208 non-null  object
#  12  CRITICAL FLAG          209789 non-null  object
#  13  SCORE                  199793 non-null  float64
#  14  GRADE                  102961 non-null  object
#  15  GRADE DATE             94208 non-null   object
#  16  RECORD DATE            209789 non-null  object
#  17  INSPECTION TYPE        207365 non-null  object
#  18  Latitude               209512 non-null  float64
#  19  Longitude              209512 non-null  float64
#  20  Community Board        206553 non-null  float64
#  21  Council District       206549 non-null  float64
#  22  Census Tract           206549 non-null  float64
#  23  BIN                    205541 non-null  float64
#  24  BBL                    209243 non-null  float64
#  25  NTA                    206553 non-null  object
#  26  Location Point1        0 non-null       float64
# dtypes: float64(10), int64(1), object(16)
# memory usage: 43.2+ MB

# %%
dohmh_df = dohmh_df.drop_duplicates()
#Change Zipcode to remove the .0
dohmh_df['ZIPCODE'] = dohmh_df['ZIPCODE'].fillna(0).astype(int)
dohmh_df
# Out:
#            CAMIS                            DBA       BORO BUILDING  \
# 0       50106271                     SOUR MOUSE  Manhattan      110
# 1       50117820  MODELLO BAR - BARCLAYS CENTER   Brooklyn      620
# 2       50141790                            NaN  Manhattan       30
# 3       50134862         FINE AND RAW CHOCOLATE   Brooklyn       70
# 4       50127238           THE DELUXE PARTY KTV     Queens     3420
# ...          ...                            ...        ...      ...
# 209784  50129459                      BLUEBERRY   Brooklyn     1849
# 209785  41444866                  PIES-N-THIGHS   Brooklyn      166
# 209786  50123805             QK Restaurant Inc.     Queens     4626
# 209787  50056510        GINBO'S HAMBURGER HOUSE      Bronx      118
# 209788  41112524           ADRIENNE'S PIZZA BAR  Manhattan       54
#
#                      STREET  ZIPCODE       PHONE       CUISINE DESCRIPTION  \
# 0           DELANCEY STREET    10002  6462567220                       NaN
# 1           ATLANTIC AVENUE    11217  9174174384                       NaN
# 2          EAST   20 STREET    10003  9176670036                       NaN
# 3              SCOTT AVENUE    11237  6462440734                       NaN
# 4                 LINDEN PL    11354  9172957843                       NaN
# ...                     ...      ...         ...                       ...
# 209784  CONEY ISLAND AVENUE    11230  3473719836  Bakery Products/Desserts
# 209785    SOUTH    4 STREET    11211  3475296090                  American
# 209786         KISSENA BLVD    11355  7189990806                   Chinese
# 209787     EAST  170 STREET    10452  3479634644                Hamburgers
# 209788         STONE STREET    10004  2122483838                   Italian
#
#        INSPECTION DATE                                           ACTION  \
# 0           01/01/1900                                              NaN
# 1           01/01/1900                                              NaN
# 2           01/01/1900                                              NaN
# 3           01/01/1900                                              NaN
# 4           01/01/1900                                              NaN
# ...                ...                                              ...
# 209784      08/03/2023  Violations were cited in the following area(s).
# 209785      08/09/2023  Violations were cited in the following area(s).
# 209786      08/01/2022  Violations were cited in the following area(s).
# 209787      09/28/2022  Violations were cited in the following area(s).
# 209788      03/10/2022  Violations were cited in the following area(s).
#
#        VIOLATION CODE                              VIOLATION DESCRIPTION  \
# 0                 NaN                                                NaN
# 1                 NaN                                                NaN
# 2                 NaN                                                NaN
# 3                 NaN                                                NaN
# 4                 NaN                                                NaN
# ...               ...                                                ...
# 209784            02A  Time/Temperature Control for Safety (TCS) food...
# 209785            04N  Filth flies or food/refuse/sewage associated w...
# 209786            06D  Food contact surface not properly washed, rins...
# 209787            08A  Establishment is not free of harborage or cond...
# 209788            04L  Evidence of mice or live mice present in facil...
#
#          CRITICAL FLAG  SCORE GRADE  GRADE DATE RECORD DATE  \
# 0       Not Applicable    NaN   NaN         NaN  12/01/2023
# 1       Not Applicable    NaN   NaN         NaN  12/01/2023
# 2       Not Applicable    NaN   NaN         NaN  12/01/2023
# 3       Not Applicable    NaN   NaN         NaN  12/01/2023
# 4       Not Applicable    NaN   NaN         NaN  12/01/2023
# ...                ...    ...   ...         ...         ...
# 209784        Critical   50.0   NaN         NaN  12/01/2023
# 209785        Critical   18.0     B  08/09/2023  12/01/2023
# 209786        Critical   29.0     C  08/01/2022  12/01/2023
# 209787    Not Critical   21.0   NaN         NaN  12/01/2023
# 209788        Critical   21.0   NaN         NaN  12/01/2023
#
#                                  INSPECTION TYPE   Latitude  Longitude  \
# 0                                            NaN  40.718640 -73.988481
# 1                                            NaN  40.683447 -73.975691
# 2                                            NaN  40.738929 -73.989221
# 3                                            NaN  40.709853 -73.922706
# 4                                            NaN  40.766275 -73.831338
# ...                                          ...        ...        ...
# 209784     Cycle Inspection / Initial Inspection  40.611980 -73.962744
# 209785          Cycle Inspection / Re-inspection  40.711289 -73.961300
# 209786  Pre-permit (Operational) / Re-inspection  40.750040 -73.818520
# 209787  Cycle Inspection / Compliance Inspection  40.839304 -73.915334
# 209788     Cycle Inspection / Initial Inspection  40.704403 -74.010211
#
#         Community Board  Council District  Census Tract        BIN  \
# 0                 103.0               1.0        1800.0  1087565.0
# 1                 302.0              35.0       12902.0  3398156.0
# 2                 105.0               2.0        5200.0  1016181.0
# 3                 301.0              34.0       44900.0  3070597.0
# 4                 407.0              20.0       86900.0  4112007.0
# ...                 ...               ...           ...        ...
# 209784            314.0              48.0       54200.0  3181708.0
# 209785            301.0              34.0       52300.0  3063458.0
# 209786            407.0              20.0       84500.0  4314742.0
# 209787            204.0              16.0       22102.0  2008084.0
# 209788            101.0               1.0         900.0  1088620.0
#
#                  BBL   NTA  Location Point1
# 0       1.004100e+09  MN27              NaN
# 1       3.011180e+09  BK37              NaN
# 2       1.008480e+09  MN13              NaN
# 3       3.029900e+09  BK90              NaN
# 4       4.049500e+09  QN22              NaN
# ...              ...   ...              ...
# 209784  3.067580e+09  BK43              NaN
# 209785  3.024460e+09  BK73              NaN
# 209786  4.051490e+09  QN22              NaN
# 209787  2.028420e+09  BX63              NaN
# 209788  1.000298e+09  MN25              NaN
#
# [209783 rows x 27 columns]

# %%
#4.Remove any HTML Encoding from the columns.
def decode_html_entities(column):
    return column.apply(lambda x: html.unescape(str(x)))

dohmh_df['DBA'] = decode_html_entities(dohmh_df['DBA'])
dohmh_df['STREET'] = decode_html_entities(dohmh_df['STREET'])
dohmh_df['ACTION'] = decode_html_entities(dohmh_df['ACTION'])
dohmh_df['VIOLATION DESCRIPTION'] = decode_html_entities(dohmh_df['VIOLATION DESCRIPTION'])

# %%
def capitalize_column(dataframe, column):
    dataframe[column]=dataframe[column].str.title()
    
    #Standardize Business Suffixes
    pattern_1 = r'\bInc\b(?!\.)'
    pattern_2 = r'\bLlc\b(?!\.)'
    pattern_3 = r'\bCorp\b(?!\.)'
    pattern_4 = r'\bIncorporated\b(?!\.)'
    dataframe[column] = dataframe[column].str.replace(pattern_1,'Inc.')
    dataframe[column] = dataframe[column].str.replace(pattern_2,'LLC')
    dataframe[column] = dataframe[column].str.replace(pattern_3,'Corp.')
    dataframe[column] = dataframe[column].str.replace(pattern_4,'Inc.')
    
    #Standardize Location Abbreviations
    pattern_st = r'\bSt$|\bSt\.$'
    dataframe[column] = dataframe[column].str.replace(pattern_st,'Street')
    pattern_av = r'\bAv$|\bAv\.$|\bAve$|\bAve\.$'
    dataframe[column] = dataframe[column].str.replace(pattern_av,'Avenue')
    pattern_ln = r'\bLn$|\bLn\.$'
    dataframe[column] = dataframe[column].str.replace(pattern_ln,'Lane')
    pattern_ln = r'\bBlvd$|\bBlvd\.$'
    dataframe[column] = dataframe[column].str.replace(pattern_ln,'Boulevard')
    
    #Change words ending in "'S" to ending in "'s" or "'T" to ending in "'t"
    pattern = r"(\w+)'S\b"
    replacement = lambda match: match.group(1).capitalize() + "'s"
    dataframe[column] = dataframe[column].str.replace(pattern, replacement, regex=True)
    pattern = r"(\w+)'T\b"
    replacement = lambda match: match.group(1).capitalize() + "'t"
    dataframe[column] = dataframe[column].str.replace(pattern, replacement, regex=True)
    return dataframe

dohmh_df = capitalize_column(dohmh_df,'DBA')
dohmh_df = capitalize_column(dohmh_df,'STREET')
dohmh_df
# Out:
# C:\Users\Prateek\AppData\Local\Temp\ipykernel_13288\1605767838.py:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   dataframe[column] = dataframe[column].str.replace(pattern_1,'Inc.')
# C:\Users\Prateek\AppData\Local\Temp\ipykernel_13288\1605767838.py:10: FutureWarning: The default value of regex will change from True to False in a future version.
#   dataframe[column] = dataframe[column].str.replace(pattern_2,'LLC')
# C:\Users\Prateek\AppData\Local\Temp\ipykernel_13288\1605767838.py:11: FutureWarning: The default value of regex will change from True to False in a future version.
#   dataframe[column] = dataframe[column].str.replace(pattern_3,'Corp.')
# C:\Users\Prateek\AppData\Local\Temp\ipykernel_13288\1605767838.py:12: FutureWarning: The default value of regex will change from True to False in a future version.
#   dataframe[column] = dataframe[column].str.replace(pattern_4,'Inc.')
# C:\Users\Prateek\AppData\Local\Temp\ipykernel_13288\1605767838.py:16: FutureWarning: The default value of regex will change from True to False in a future version.
#   dataframe[column] = dataframe[column].str.replace(pattern_st,'Street')
# C:\Users\Prateek\AppData\Local\Temp\ipykernel_13288\1605767838.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
#   dataframe[column] = dataframe[column].str.replace(pattern_av,'Avenue')
# C:\Users\Prateek\AppData\Local\Temp\ipykernel_13288\1605767838.py:20: FutureWarning: The default value of regex will change from True to False in a future version.
#   dataframe[column] = dataframe[column].str.replace(pattern_ln,'Lane')
# C:\Users\Prateek\AppData\Local\Temp\ipykernel_13288\1605767838.py:22: FutureWarning: The default value of regex will change from True to False in a future version.
#   dataframe[column] = dataframe[column].str.replace(pattern_ln,'Boulevard')
#            CAMIS                            DBA       BORO BUILDING  \
# 0       50106271                     Sour Mouse  Manhattan      110
# 1       50117820  Modello Bar - Barclays Center   Brooklyn      620
# 2       50141790                            Nan  Manhattan       30
# 3       50134862         Fine And Raw Chocolate   Brooklyn       70
# 4       50127238           The Deluxe Party Ktv     Queens     3420
# ...          ...                            ...        ...      ...
# 209784  50129459                      Blueberry   Brooklyn     1849
# 209785  41444866                  Pies-N-Thighs   Brooklyn      166
# 209786  50123805             Qk Restaurant Inc.     Queens     4626
# 209787  50056510        Ginbo's Hamburger House      Bronx      118
# 209788  41112524           Adrienne's Pizza Bar  Manhattan       54
#
#                      STREET  ZIPCODE       PHONE       CUISINE DESCRIPTION  \
# 0           Delancey Street    10002  6462567220                       NaN
# 1           Atlantic Avenue    11217  9174174384                       NaN
# 2          East   20 Street    10003  9176670036                       NaN
# 3              Scott Avenue    11237  6462440734                       NaN
# 4                 Linden Pl    11354  9172957843                       NaN
# ...                     ...      ...         ...                       ...
# 209784  Coney Island Avenue    11230  3473719836  Bakery Products/Desserts
# 209785    South    4 Street    11211  3475296090                  American
# 209786    Kissena Boulevard    11355  7189990806                   Chinese
# 209787     East  170 Street    10452  3479634644                Hamburgers
# 209788         Stone Street    10004  2122483838                   Italian
#
#        INSPECTION DATE                                           ACTION  \
# 0           01/01/1900                                              nan
# 1           01/01/1900                                              nan
# 2           01/01/1900                                              nan
# 3           01/01/1900                                              nan
# 4           01/01/1900                                              nan
# ...                ...                                              ...
# 209784      08/03/2023  Violations were cited in the following area(s).
# 209785      08/09/2023  Violations were cited in the following area(s).
# 209786      08/01/2022  Violations were cited in the following area(s).
# 209787      09/28/2022  Violations were cited in the following area(s).
# 209788      03/10/2022  Violations were cited in the following area(s).
#
#        VIOLATION CODE                              VIOLATION DESCRIPTION  \
# 0                 NaN                                                nan
# 1                 NaN                                                nan
# 2                 NaN                                                nan
# 3                 NaN                                                nan
# 4                 NaN                                                nan
# ...               ...                                                ...
# 209784            02A  Time/Temperature Control for Safety (TCS) food...
# 209785            04N  Filth flies or food/refuse/sewage associated w...
# 209786            06D  Food contact surface not properly washed, rins...
# 209787            08A  Establishment is not free of harborage or cond...
# 209788            04L  Evidence of mice or live mice present in facil...
#
#          CRITICAL FLAG  SCORE GRADE  GRADE DATE RECORD DATE  \
# 0       Not Applicable    NaN   NaN         NaN  12/01/2023
# 1       Not Applicable    NaN   NaN         NaN  12/01/2023
# 2       Not Applicable    NaN   NaN         NaN  12/01/2023
# 3       Not Applicable    NaN   NaN         NaN  12/01/2023
# 4       Not Applicable    NaN   NaN         NaN  12/01/2023
# ...                ...    ...   ...         ...         ...
# 209784        Critical   50.0   NaN         NaN  12/01/2023
# 209785        Critical   18.0     B  08/09/2023  12/01/2023
# 209786        Critical   29.0     C  08/01/2022  12/01/2023
# 209787    Not Critical   21.0   NaN         NaN  12/01/2023
# 209788        Critical   21.0   NaN         NaN  12/01/2023
#
#                                  INSPECTION TYPE   Latitude  Longitude  \
# 0                                            NaN  40.718640 -73.988481
# 1                                            NaN  40.683447 -73.975691
# 2                                            NaN  40.738929 -73.989221
# 3                                            NaN  40.709853 -73.922706
# 4                                            NaN  40.766275 -73.831338
# ...                                          ...        ...        ...
# 209784     Cycle Inspection / Initial Inspection  40.611980 -73.962744
# 209785          Cycle Inspection / Re-inspection  40.711289 -73.961300
# 209786  Pre-permit (Operational) / Re-inspection  40.750040 -73.818520
# 209787  Cycle Inspection / Compliance Inspection  40.839304 -73.915334
# 209788     Cycle Inspection / Initial Inspection  40.704403 -74.010211
#
#         Community Board  Council District  Census Tract        BIN  \
# 0                 103.0               1.0        1800.0  1087565.0
# 1                 302.0              35.0       12902.0  3398156.0
# 2                 105.0               2.0        5200.0  1016181.0
# 3                 301.0              34.0       44900.0  3070597.0
# 4                 407.0              20.0       86900.0  4112007.0
# ...                 ...               ...           ...        ...
# 209784            314.0              48.0       54200.0  3181708.0
# 209785            301.0              34.0       52300.0  3063458.0
# 209786            407.0              20.0       84500.0  4314742.0
# 209787            204.0              16.0       22102.0  2008084.0
# 209788            101.0               1.0         900.0  1088620.0
#
#                  BBL   NTA  Location Point1
# 0       1.004100e+09  MN27              NaN
# 1       3.011180e+09  BK37              NaN
# 2       1.008480e+09  MN13              NaN
# 3       3.029900e+09  BK90              NaN
# 4       4.049500e+09  QN22              NaN
# ...              ...   ...              ...
# 209784  3.067580e+09  BK43              NaN
# 209785  3.024460e+09  BK73              NaN
# 209786  4.051490e+09  QN22              NaN
# 209787  2.028420e+09  BX63              NaN
# 209788  1.000298e+09  MN25              NaN
#
# [209783 rows x 27 columns]

# %%
dohmh_df.dropna(subset=['DBA'], inplace=True)
dohmh_df.dropna(subset=['STREET'], inplace=True)
dohmh_df=dohmh_df[dohmh_df['BORO']!='0']
dohmh_df
# Out:
#            CAMIS                            DBA       BORO BUILDING  \
# 0       50106271                     Sour Mouse  Manhattan      110
# 1       50117820  Modello Bar - Barclays Center   Brooklyn      620
# 2       50141790                            Nan  Manhattan       30
# 3       50134862         Fine And Raw Chocolate   Brooklyn       70
# 4       50127238           The Deluxe Party Ktv     Queens     3420
# ...          ...                            ...        ...      ...
# 209784  50129459                      Blueberry   Brooklyn     1849
# 209785  41444866                  Pies-N-Thighs   Brooklyn      166
# 209786  50123805             Qk Restaurant Inc.     Queens     4626
# 209787  50056510        Ginbo's Hamburger House      Bronx      118
# 209788  41112524           Adrienne's Pizza Bar  Manhattan       54
#
#                      STREET  ZIPCODE       PHONE       CUISINE DESCRIPTION  \
# 0           Delancey Street    10002  6462567220                       NaN
# 1           Atlantic Avenue    11217  9174174384                       NaN
# 2          East   20 Street    10003  9176670036                       NaN
# 3              Scott Avenue    11237  6462440734                       NaN
# 4                 Linden Pl    11354  9172957843                       NaN
# ...                     ...      ...         ...                       ...
# 209784  Coney Island Avenue    11230  3473719836  Bakery Products/Desserts
# 209785    South    4 Street    11211  3475296090                  American
# 209786    Kissena Boulevard    11355  7189990806                   Chinese
# 209787     East  170 Street    10452  3479634644                Hamburgers
# 209788         Stone Street    10004  2122483838                   Italian
#
#        INSPECTION DATE                                           ACTION  \
# 0           01/01/1900                                              nan
# 1           01/01/1900                                              nan
# 2           01/01/1900                                              nan
# 3           01/01/1900                                              nan
# 4           01/01/1900                                              nan
# ...                ...                                              ...
# 209784      08/03/2023  Violations were cited in the following area(s).
# 209785      08/09/2023  Violations were cited in the following area(s).
# 209786      08/01/2022  Violations were cited in the following area(s).
# 209787      09/28/2022  Violations were cited in the following area(s).
# 209788      03/10/2022  Violations were cited in the following area(s).
#
#        VIOLATION CODE                              VIOLATION DESCRIPTION  \
# 0                 NaN                                                nan
# 1                 NaN                                                nan
# 2                 NaN                                                nan
# 3                 NaN                                                nan
# 4                 NaN                                                nan
# ...               ...                                                ...
# 209784            02A  Time/Temperature Control for Safety (TCS) food...
# 209785            04N  Filth flies or food/refuse/sewage associated w...
# 209786            06D  Food contact surface not properly washed, rins...
# 209787            08A  Establishment is not free of harborage or cond...
# 209788            04L  Evidence of mice or live mice present in facil...
#
#          CRITICAL FLAG  SCORE GRADE  GRADE DATE RECORD DATE  \
# 0       Not Applicable    NaN   NaN         NaN  12/01/2023
# 1       Not Applicable    NaN   NaN         NaN  12/01/2023
# 2       Not Applicable    NaN   NaN         NaN  12/01/2023
# 3       Not Applicable    NaN   NaN         NaN  12/01/2023
# 4       Not Applicable    NaN   NaN         NaN  12/01/2023
# ...                ...    ...   ...         ...         ...
# 209784        Critical   50.0   NaN         NaN  12/01/2023
# 209785        Critical   18.0     B  08/09/2023  12/01/2023
# 209786        Critical   29.0     C  08/01/2022  12/01/2023
# 209787    Not Critical   21.0   NaN         NaN  12/01/2023
# 209788        Critical   21.0   NaN         NaN  12/01/2023
#
#                                  INSPECTION TYPE   Latitude  Longitude  \
# 0                                            NaN  40.718640 -73.988481
# 1                                            NaN  40.683447 -73.975691
# 2                                            NaN  40.738929 -73.989221
# 3                                            NaN  40.709853 -73.922706
# 4                                            NaN  40.766275 -73.831338
# ...                                          ...        ...        ...
# 209784     Cycle Inspection / Initial Inspection  40.611980 -73.962744
# 209785          Cycle Inspection / Re-inspection  40.711289 -73.961300
# 209786  Pre-permit (Operational) / Re-inspection  40.750040 -73.818520
# 209787  Cycle Inspection / Compliance Inspection  40.839304 -73.915334
# 209788     Cycle Inspection / Initial Inspection  40.704403 -74.010211
#
#         Community Board  Council District  Census Tract        BIN  \
# 0                 103.0               1.0        1800.0  1087565.0
# 1                 302.0              35.0       12902.0  3398156.0
# 2                 105.0               2.0        5200.0  1016181.0
# 3                 301.0              34.0       44900.0  3070597.0
# 4                 407.0              20.0       86900.0  4112007.0
# ...                 ...               ...           ...        ...
# 209784            314.0              48.0       54200.0  3181708.0
# 209785            301.0              34.0       52300.0  3063458.0
# 209786            407.0              20.0       84500.0  4314742.0
# 209787            204.0              16.0       22102.0  2008084.0
# 209788            101.0               1.0         900.0  1088620.0
#
#                  BBL   NTA  Location Point1
# 0       1.004100e+09  MN27              NaN
# 1       3.011180e+09  BK37              NaN
# 2       1.008480e+09  MN13              NaN
# 3       3.029900e+09  BK90              NaN
# 4       4.049500e+09  QN22              NaN
# ...              ...   ...              ...
# 209784  3.067580e+09  BK43              NaN
# 209785  3.024460e+09  BK73              NaN
# 209786  4.051490e+09  QN22              NaN
# 209787  2.028420e+09  BX63              NaN
# 209788  1.000298e+09  MN25              NaN
#
# [209772 rows x 27 columns]

# %%
def make_ordinal(number_str):
    # Use regex to find standalone numbers
    matches = re.findall(r'\b\d+\b', str(number_str))
    
    # Apply ordinal conversion to standalone numbers
    for match in matches:
        number = int(match)
        if number % 100 in [11, 12, 13]:
            suffix = 'th'
        else:
            suffix = {1: 'st', 2: 'nd', 3: 'rd'}.get(number % 10, 'th')
        number_with_suffix = str(number) + suffix
        
        # Replace the standalone number in the original string
        number_str = re.sub(r'\b{}\b'.format(match), number_with_suffix, str(number_str))

    return number_str

# Make Ordinal Numbers from Words
def words_to_ordinal(address):
    word_to_number = {'First': '1st', 'Second': '2nd', 'Third': '3rd', 'Fourth': '4th', 'Fifth': '5th', 'Sixth': '6th' \
                     , 'Seventh': '7th', 'Eight': '8th', 'Ninth': '9th', 'Tenth': '10th'}
    
    # Use regex to find words in the address and replace them with ordinal numbers
    for word, ordinal in word_to_number.items():
        address = re.sub(r'\b{}\b'.format(word), ordinal, address)

    return address

# Convert Capital suffixes to small
def convert_suffixes(number_str):
    # Use regex to find words with numbers followed by 'Th', 'Rd', 'Nd', 'St'
    matches = re.finditer(r'(\d+)([TtRrNnSs][HhDdNnTt])\b', str(number_str))
    
    # Apply the conversion to matched words
    for match in matches:
        number, suffix = match.groups()
        number_str = number_str.replace(match.group(0), f"{number}{suffix.lower()}")
    
    return number_str

dohmh_df['STREET']=dohmh_df['STREET'].apply(make_ordinal)
dohmh_df['STREET']=dohmh_df['STREET'].apply(words_to_ordinal)
dohmh_df['STREET']=dohmh_df['STREET'].apply(convert_suffixes)
dohmh_df['DBA']=dohmh_df['DBA'].apply(convert_suffixes)
dohmh_df
# Out:
# C:\Users\Prateek\AppData\Local\Temp\ipykernel_13288\3247547374.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dohmh_df['STREET']=dohmh_df['STREET'].apply(make_ordinal)
# C:\Users\Prateek\AppData\Local\Temp\ipykernel_13288\3247547374.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dohmh_df['STREET']=dohmh_df['STREET'].apply(words_to_ordinal)
# C:\Users\Prateek\AppData\Local\Temp\ipykernel_13288\3247547374.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dohmh_df['STREET']=dohmh_df['STREET'].apply(convert_suffixes)
# C:\Users\Prateek\AppData\Local\Temp\ipykernel_13288\3247547374.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dohmh_df['DBA']=dohmh_df['DBA'].apply(convert_suffixes)
#            CAMIS                            DBA       BORO BUILDING  \
# 0       50106271                     Sour Mouse  Manhattan      110
# 1       50117820  Modello Bar - Barclays Center   Brooklyn      620
# 2       50141790                            Nan  Manhattan       30
# 3       50134862         Fine And Raw Chocolate   Brooklyn       70
# 4       50127238           The Deluxe Party Ktv     Queens     3420
# ...          ...                            ...        ...      ...
# 209784  50129459                      Blueberry   Brooklyn     1849
# 209785  41444866                  Pies-N-Thighs   Brooklyn      166
# 209786  50123805             Qk Restaurant Inc.     Queens     4626
# 209787  50056510        Ginbo's Hamburger House      Bronx      118
# 209788  41112524           Adrienne's Pizza Bar  Manhattan       54
#
#                      STREET  ZIPCODE       PHONE       CUISINE DESCRIPTION  \
# 0           Delancey Street    10002  6462567220                       NaN
# 1           Atlantic Avenue    11217  9174174384                       NaN
# 2        East   20th Street    10003  9176670036                       NaN
# 3              Scott Avenue    11237  6462440734                       NaN
# 4                 Linden Pl    11354  9172957843                       NaN
# ...                     ...      ...         ...                       ...
# 209784  Coney Island Avenue    11230  3473719836  Bakery Products/Desserts
# 209785  South    4th Street    11211  3475296090                  American
# 209786    Kissena Boulevard    11355  7189990806                   Chinese
# 209787   East  170th Street    10452  3479634644                Hamburgers
# 209788         Stone Street    10004  2122483838                   Italian
#
#        INSPECTION DATE                                           ACTION  \
# 0           01/01/1900                                              nan
# 1           01/01/1900                                              nan
# 2           01/01/1900                                              nan
# 3           01/01/1900                                              nan
# 4           01/01/1900                                              nan
# ...                ...                                              ...
# 209784      08/03/2023  Violations were cited in the following area(s).
# 209785      08/09/2023  Violations were cited in the following area(s).
# 209786      08/01/2022  Violations were cited in the following area(s).
# 209787      09/28/2022  Violations were cited in the following area(s).
# 209788      03/10/2022  Violations were cited in the following area(s).
#
#        VIOLATION CODE                              VIOLATION DESCRIPTION  \
# 0                 NaN                                                nan
# 1                 NaN                                                nan
# 2                 NaN                                                nan
# 3                 NaN                                                nan
# 4                 NaN                                                nan
# ...               ...                                                ...
# 209784            02A  Time/Temperature Control for Safety (TCS) food...
# 209785            04N  Filth flies or food/refuse/sewage associated w...
# 209786            06D  Food contact surface not properly washed, rins...
# 209787            08A  Establishment is not free of harborage or cond...
# 209788            04L  Evidence of mice or live mice present in facil...
#
#          CRITICAL FLAG  SCORE GRADE  GRADE DATE RECORD DATE  \
# 0       Not Applicable    NaN   NaN         NaN  12/01/2023
# 1       Not Applicable    NaN   NaN         NaN  12/01/2023
# 2       Not Applicable    NaN   NaN         NaN  12/01/2023
# 3       Not Applicable    NaN   NaN         NaN  12/01/2023
# 4       Not Applicable    NaN   NaN         NaN  12/01/2023
# ...                ...    ...   ...         ...         ...
# 209784        Critical   50.0   NaN         NaN  12/01/2023
# 209785        Critical   18.0     B  08/09/2023  12/01/2023
# 209786        Critical   29.0     C  08/01/2022  12/01/2023
# 209787    Not Critical   21.0   NaN         NaN  12/01/2023
# 209788        Critical   21.0   NaN         NaN  12/01/2023
#
#                                  INSPECTION TYPE   Latitude  Longitude  \
# 0                                            NaN  40.718640 -73.988481
# 1                                            NaN  40.683447 -73.975691
# 2                                            NaN  40.738929 -73.989221
# 3                                            NaN  40.709853 -73.922706
# 4                                            NaN  40.766275 -73.831338
# ...                                          ...        ...        ...
# 209784     Cycle Inspection / Initial Inspection  40.611980 -73.962744
# 209785          Cycle Inspection / Re-inspection  40.711289 -73.961300
# 209786  Pre-permit (Operational) / Re-inspection  40.750040 -73.818520
# 209787  Cycle Inspection / Compliance Inspection  40.839304 -73.915334
# 209788     Cycle Inspection / Initial Inspection  40.704403 -74.010211
#
#         Community Board  Council District  Census Tract        BIN  \
# 0                 103.0               1.0        1800.0  1087565.0
# 1                 302.0              35.0       12902.0  3398156.0
# 2                 105.0               2.0        5200.0  1016181.0
# 3                 301.0              34.0       44900.0  3070597.0
# 4                 407.0              20.0       86900.0  4112007.0
# ...                 ...               ...           ...        ...
# 209784            314.0              48.0       54200.0  3181708.0
# 209785            301.0              34.0       52300.0  3063458.0
# 209786            407.0              20.0       84500.0  4314742.0
# 209787            204.0              16.0       22102.0  2008084.0
# 209788            101.0               1.0         900.0  1088620.0
#
#                  BBL   NTA  Location Point1
# 0       1.004100e+09  MN27              NaN
# 1       3.011180e+09  BK37              NaN
# 2       1.008480e+09  MN13              NaN
# 3       3.029900e+09  BK90              NaN
# 4       4.049500e+09  QN22              NaN
# ...              ...   ...              ...
# 209784  3.067580e+09  BK43              NaN
# 209785  3.024460e+09  BK73              NaN
# 209786  4.051490e+09  QN22              NaN
# 209787  2.028420e+09  BX63              NaN
# 209788  1.000298e+09  MN25              NaN
#
# [209772 rows x 27 columns]

# %%
dohmh_df['Business Address'] = dohmh_df['BUILDING'] + " "+ dohmh_df['STREET'] + ", " +dohmh_df['BORO'] + ", NY"
dohmh_df
# Out:
# C:\Users\Prateek\AppData\Local\Temp\ipykernel_13288\3077022051.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dohmh_df['Business Address'] = dohmh_df['BUILDING'] + " "+ dohmh_df['STREET'] + ", " +dohmh_df['BORO'] + ", NY"
#            CAMIS                            DBA       BORO BUILDING  \
# 0       50106271                     Sour Mouse  Manhattan      110
# 1       50117820  Modello Bar - Barclays Center   Brooklyn      620
# 2       50141790                            Nan  Manhattan       30
# 3       50134862         Fine And Raw Chocolate   Brooklyn       70
# 4       50127238           The Deluxe Party Ktv     Queens     3420
# ...          ...                            ...        ...      ...
# 209784  50129459                      Blueberry   Brooklyn     1849
# 209785  41444866                  Pies-N-Thighs   Brooklyn      166
# 209786  50123805             Qk Restaurant Inc.     Queens     4626
# 209787  50056510        Ginbo's Hamburger House      Bronx      118
# 209788  41112524           Adrienne's Pizza Bar  Manhattan       54
#
#                      STREET  ZIPCODE       PHONE       CUISINE DESCRIPTION  \
# 0           Delancey Street    10002  6462567220                       NaN
# 1           Atlantic Avenue    11217  9174174384                       NaN
# 2        East   20th Street    10003  9176670036                       NaN
# 3              Scott Avenue    11237  6462440734                       NaN
# 4                 Linden Pl    11354  9172957843                       NaN
# ...                     ...      ...         ...                       ...
# 209784  Coney Island Avenue    11230  3473719836  Bakery Products/Desserts
# 209785  South    4th Street    11211  3475296090                  American
# 209786    Kissena Boulevard    11355  7189990806                   Chinese
# 209787   East  170th Street    10452  3479634644                Hamburgers
# 209788         Stone Street    10004  2122483838                   Italian
#
#        INSPECTION DATE                                           ACTION  \
# 0           01/01/1900                                              nan
# 1           01/01/1900                                              nan
# 2           01/01/1900                                              nan
# 3           01/01/1900                                              nan
# 4           01/01/1900                                              nan
# ...                ...                                              ...
# 209784      08/03/2023  Violations were cited in the following area(s).
# 209785      08/09/2023  Violations were cited in the following area(s).
# 209786      08/01/2022  Violations were cited in the following area(s).
# 209787      09/28/2022  Violations were cited in the following area(s).
# 209788      03/10/2022  Violations were cited in the following area(s).
#
#        VIOLATION CODE                              VIOLATION DESCRIPTION  \
# 0                 NaN                                                nan
# 1                 NaN                                                nan
# 2                 NaN                                                nan
# 3                 NaN                                                nan
# 4                 NaN                                                nan
# ...               ...                                                ...
# 209784            02A  Time/Temperature Control for Safety (TCS) food...
# 209785            04N  Filth flies or food/refuse/sewage associated w...
# 209786            06D  Food contact surface not properly washed, rins...
# 209787            08A  Establishment is not free of harborage or cond...
# 209788            04L  Evidence of mice or live mice present in facil...
#
#          CRITICAL FLAG  SCORE GRADE  GRADE DATE RECORD DATE  \
# 0       Not Applicable    NaN   NaN         NaN  12/01/2023
# 1       Not Applicable    NaN   NaN         NaN  12/01/2023
# 2       Not Applicable    NaN   NaN         NaN  12/01/2023
# 3       Not Applicable    NaN   NaN         NaN  12/01/2023
# 4       Not Applicable    NaN   NaN         NaN  12/01/2023
# ...                ...    ...   ...         ...         ...
# 209784        Critical   50.0   NaN         NaN  12/01/2023
# 209785        Critical   18.0     B  08/09/2023  12/01/2023
# 209786        Critical   29.0     C  08/01/2022  12/01/2023
# 209787    Not Critical   21.0   NaN         NaN  12/01/2023
# 209788        Critical   21.0   NaN         NaN  12/01/2023
#
#                                  INSPECTION TYPE   Latitude  Longitude  \
# 0                                            NaN  40.718640 -73.988481
# 1                                            NaN  40.683447 -73.975691
# 2                                            NaN  40.738929 -73.989221
# 3                                            NaN  40.709853 -73.922706
# 4                                            NaN  40.766275 -73.831338
# ...                                          ...        ...        ...
# 209784     Cycle Inspection / Initial Inspection  40.611980 -73.962744
# 209785          Cycle Inspection / Re-inspection  40.711289 -73.961300
# 209786  Pre-permit (Operational) / Re-inspection  40.750040 -73.818520
# 209787  Cycle Inspection / Compliance Inspection  40.839304 -73.915334
# 209788     Cycle Inspection / Initial Inspection  40.704403 -74.010211
#
#         Community Board  Council District  Census Tract        BIN  \
# 0                 103.0               1.0        1800.0  1087565.0
# 1                 302.0              35.0       12902.0  3398156.0
# 2                 105.0               2.0        5200.0  1016181.0
# 3                 301.0              34.0       44900.0  3070597.0
# 4                 407.0              20.0       86900.0  4112007.0
# ...                 ...               ...           ...        ...
# 209784            314.0              48.0       54200.0  3181708.0
# 209785            301.0              34.0       52300.0  3063458.0
# 209786            407.0              20.0       84500.0  4314742.0
# 209787            204.0              16.0       22102.0  2008084.0
# 209788            101.0               1.0         900.0  1088620.0
#
#                  BBL   NTA  Location Point1  \
# 0       1.004100e+09  MN27              NaN
# 1       3.011180e+09  BK37              NaN
# 2       1.008480e+09  MN13              NaN
# 3       3.029900e+09  BK90              NaN
# 4       4.049500e+09  QN22              NaN
# ...              ...   ...              ...
# 209784  3.067580e+09  BK43              NaN
# 209785  3.024460e+09  BK73              NaN
# 209786  4.051490e+09  QN22              NaN
# 209787  2.028420e+09  BX63              NaN
# 209788  1.000298e+09  MN25              NaN
#
#                               Business Address
# 0           110 Delancey Street, Manhattan, NY
# 1            620 Atlantic Avenue, Brooklyn, NY
# 2         30 East   20th Street, Manhattan, NY
# 3                70 Scott Avenue, Brooklyn, NY
# 4                   3420 Linden Pl, Queens, NY
# ...                                        ...
# 209784  1849 Coney Island Avenue, Brooklyn, NY
# 209785   166 South    4th Street, Brooklyn, NY
# 209786      4626 Kissena Boulevard, Queens, NY
# 209787       118 East  170th Street, Bronx, NY
# 209788          54 Stone Street, Manhattan, NY
#
# [209772 rows x 28 columns]

# %%
nta_df = pd.read_csv("nta_data.csv")
nta_df
# Out:
#       NTA                              Areas
# 0    BX98                      Rikers Island
# 1    SI99    park-cemetery-etc-Staten Island
# 2    QN99           park-cemetery-etc-Queens
# 3    QN98                            Airport
# 4    MN50     Stuyvesant Town-Cooper Village
# ..    ...                                ...
# 190  BK35                 Stuyvesant Heights
# 191  BK81                        Brownsville
# 192  BK82                      East New York
# 193  MN03  Central Harlem North-Polo Grounds
# 194  BK61                Crown Heights North
#
# [195 rows x 2 columns]

# %%
result_dict = nta_df.set_index('NTA')['Areas'].to_dict()

# %%
result_dict
# Out:
# {'BX98': 'Rikers Island',
#  'SI99': 'park-cemetery-etc-Staten Island',
#  'QN99': 'park-cemetery-etc-Queens',
#  'QN98': 'Airport',
#  'MN50': 'Stuyvesant Town-Cooper Village',
#  'BK09': 'Brooklyn Heights-Cobble Hill',
#  'QN41': 'Fresh Meadows-Utopia',
#  'BX99': 'park-cemetery-etc-Bronx',
#  'BK99': 'park-cemetery-etc-Brooklyn',
#  'QN45': 'Douglas Manor-Douglaston-Little Neck',
#  'QN47': 'Ft. Totten-Bay Terrace-Clearview',
#  'QN62': 'Queensboro Hill',
#  'QN44': 'Glen Oaks-Floral Park-New Hyde Park',
#  'BK46': 'Ocean Parkway South',
#  'QN48': 'Auburndale',
#  'BX22': 'North Riverdale-Fieldston-Riverdale',
#  'QN42': 'Oakland Gardens',
#  'QN43': 'Bellerose',
#  'SI32': 'Rossville-Woodrow',
#  'SI11': 'Charleston-Richmond Valley-Tottenville',
#  'SI25': 'Oakwood-Oakwood Beach',
#  'QN60': 'Kew Gardens',
#  'BK23': 'West Brighton',
#  'QN18': 'Rego Park',
#  'BX10': 'Pelham Bay-Country Club-City Island',
#  'SI48': 'Arden Heights',
#  'SI07': 'Westerleigh',
#  'MN40': 'Upper East Side-Carnegie Hill',
#  'SI01': "Annadale-Huguenot-Prince's Bay-Eltingville",
#  'BK40': 'Windsor Terrace',
#  'MN25': 'Battery Park City-Lower Manhattan',
#  'SI35': 'New Brighton-Silver Lake',
#  'SI54': 'Great Kills',
#  'QN21': 'Middle Village',
#  'QN49': 'Whitestone',
#  'QN30': 'Maspeth',
#  'QN50': 'Elmhurst-Maspeth',
#  'MN19': 'Turtle Bay-East Midtown',
#  'MN21': 'Gramercy',
#  'SI36': 'Old Town-Dongan Hills-South Beach',
#  'QN63': 'Woodside',
#  'MN99': 'park-cemetery-etc-Manhattan',
#  'QN37': 'Kew Gardens Hills',
#  'BX29': 'Spuyten Duyvil-Kingsbridge',
#  'BK25': 'Homecrest',
#  'QN46': 'Bayside-Bayside Hills',
#  'QN10': 'Breezy Point-Belle Harbor-Rockaway Park-Broad Channel',
#  'QN56': 'Ozone Park',
#  'BK19': 'Brighton Beach',
#  'BK72': 'Williamsburg',
#  'QN06': 'Jamaica Estates-Holliswood',
#  'BK27': 'Bath Beach',
#  'QN52': 'East Flushing',
#  'SI24': 'Todt Hill-Emerson Hill-Heartland Village-Lighthouse Hill',
#  'BK45': 'Georgetown-Marine Park-Bergen Beach-Mill Basin',
#  'QN57': 'Lindenwood-Howard Beach',
#  'SI14': 'Grasmere-Arrochar-Ft. Wadsworth',
#  'SI05': 'New Springville-Bloomfield-Travis',
#  'BK44': 'Madison',
#  'SI45': 'New Dorp-Midland Beach',
#  'BK30': 'Dyker Heights',
#  'QN23': 'College Point',
#  'MN31': 'Lenox Hill-Roosevelt Island',
#  'QN17': 'Forest Hills',
#  'QN19': 'Glendale',
#  'QN51': 'Murray Hill',
#  'QN72': 'Steinway',
#  'MN17': 'Midtown-Midtown South',
#  'MN24': 'SoHo-TriBeCa-Civic Center-Little Italy',
#  'BK41': 'Kensington-Ocean Parkway',
#  'QN33': 'Cambria Heights',
#  'QN38': 'Pomonok-Flushing Heights-Hillcrest',
#  'BK43': 'Midwood',
#  'QN35': 'Briarwood-Jamaica Hills',
#  'BX49': 'Pelham Parkway',
#  'BK76': 'Greenpoint',
#  'BK88': 'Borough Park',
#  'QN03': 'Springfield Gardens South-Brookville',
#  'BK93': 'Starrett City',
#  'MN23': 'West Village',
#  'QN05': 'Rosedale',
#  'MN14': 'Lincoln Square',
#  'SI28': 'Port Richmond',
#  'MN32': 'Yorkville',
#  'QN31': 'Hunters Point-Sunnyside-West Maspeth',
#  'BK29': 'Bensonhurst East',
#  'BX31': 'Allerton-Pelham Gardens',
#  'BX37': 'Van Nest-Morris Park-Westchester Square',
#  'BK28': 'Bensonhurst West',
#  'QN07': 'Hollis',
#  'BK31': 'Bay Ridge',
#  'BK26': 'Gravesend',
#  'BX59': 'Westchester-Unionport',
#  'QN27': 'East Elmhurst',
#  'QN29': 'Elmhurst',
#  'MN15': 'Clinton',
#  'BX52': 'Schuylerville-Throgs Neck-Edgewater Park',
#  'SI08': 'Grymes Hill-Clifton-Fox Hills',
#  'QN22': 'Flushing',
#  'MN20': 'Murray Hill-Kips Bay',
#  'QN66': 'Laurelton',
#  'QN54': 'Richmond Hill',
#  'QN71': 'Old Astoria',
#  'BK64': 'Prospect Heights',
#  'QN53': 'Woodhaven',
#  'BK17': 'Sheepshead Bay-Gerritsen Beach-Manhattan Beach',
#  'BX13': 'Co-op City',
#  'QN70': 'Astoria',
#  'BK34': 'Sunset Park East',
#  'BK37': 'Park Slope-Gowanus',
#  'QN02': 'Springfield Gardens North',
#  'QN28': 'Jackson Heights',
#  'QN25': 'Corona',
#  'QN68': 'Queensbridge-Ravenswood-Long Island City',
#  'BX46': 'Parkchester',
#  'MN27': 'Chinatown',
#  'MN22': 'East Village',
#  'BX62': 'Woodlawn-Wakefield',
#  'BX07': 'Bronxdale',
#  'BK90': 'East Williamsburg',
#  'QN20': 'Ridgewood',
#  'BK73': 'North Side-South Side',
#  'BK95': 'Erasmus',
#  'SI37': 'Stapleton-Rosebank',
#  'SI12': "Mariner's Harbor-Arlington-Port Ivory-Graniteville",
#  'QN26': 'North Corona',
#  'BK69': 'Clinton Hill',
#  'BK58': 'Flatlands',
#  'QN34': 'Queens Village',
#  'BK33': 'Carroll Gardens-Columbia Street-Red Hook',
#  'BX06': 'Belmont',
#  'BK32': 'Sunset Park West',
#  'BX75': 'Crotona Park East',
#  'QN55': 'South Ozone Park',
#  'BX33': 'Longwood',
#  'MN13': 'Hudson Yards-Chelsea-Flatiron-Union Square',
#  'QN61': 'Jamaica',
#  'BK68': 'Fort Greene',
#  'BX43': 'Norwood',
#  'BX28': 'Van Cortlandt Village',
#  'BK91': 'East Flatbush-Farragut',
#  'BX30': 'Kingsbridge Heights',
#  'MN09': 'Morningside Heights',
#  'BX03': 'Eastchester-Edenwald-Baychester',
#  'BK63': 'Crown Heights South',
#  'MN01': 'Marble Hill-Inwood',
#  'BX40': 'Fordham South',
#  'SI22': 'West New Brighton-New Brighton-St. George',
#  'BX08': 'West Farms-Bronx River',
#  'MN06': 'Manhattanville',
#  'BX55': 'Soundview-Bruckner',
#  'BK38': 'DUMBO-Vinegar Hill-Downtown Brooklyn-Boerum Hill',
#  'QN76': 'Baisley Park',
#  'BX44': 'Williamsbridge-Olinville',
#  'BX26': 'Highbridge',
#  'BK96': 'Rugby-Remsen Village',
#  'MN35': 'Washington Heights North',
#  'QN08': 'St. Albans',
#  'BX63': 'West Concourse',
#  'QN15': 'Far Rockaway-Bayswater',
#  'BK50': 'Canarsie',
#  'BX17': 'East Tremont',
#  'BX27': 'Hunts Point',
#  'BX34': 'Melrose South-Mott Haven North',
#  'BK21': 'Seagate-Coney Island',
#  'MN12': 'Upper West Side',
#  'BK83': 'Cypress Hills-City Line',
#  'BX05': 'Bedford Park-Fordham North',
#  'QN12': 'Hammels-Arverne-Edgemere',
#  'BX01': 'Claremont-Bathgate',
#  'BX09': 'Soundview-Castle Hill-Clason Point-Harding Park',
#  'BX35': 'Morrisania-Melrose',
#  'BK60': 'Prospect Lefferts Gardens-Wingate',
#  'QN01': 'South Jamaica',
#  'BK79': 'Ocean Hill',
#  'BK85': 'East New York (Pennsylvania Ave)',
#  'BX41': 'Mount Hope',
#  'BK77': 'Bushwick North',
#  'BX36': 'University Heights-Morris Heights',
#  'BX14': 'East Concourse-Concourse Village',
#  'BK42': 'Flatbush',
#  'MN04': 'Hamilton Heights',
#  'BX39': 'Mott Haven-Port Morris',
#  'MN36': 'Washington Heights South',
#  'MN11': 'Central Harlem South',
#  'MN28': 'Lower East Side',
#  'MN33': 'East Harlem South',
#  'BK78': 'Bushwick South',
#  'MN34': 'East Harlem North',
#  'BK75': 'Bedford',
#  'BK35': 'Stuyvesant Heights',
#  'BK81': 'Brownsville',
#  'BK82': 'East New York',
#  'MN03': 'Central Harlem North-Polo Grounds',
#  'BK61': 'Crown Heights North'}

# %%
dohmh_df['NTA'] = dohmh_df['NTA'].map(result_dict)
dohmh_df
# Out:
# C:\Users\Prateek\AppData\Local\Temp\ipykernel_13288\3464650564.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dohmh_df['NTA'] = dohmh_df['NTA'].map(result_dict)
#            CAMIS                            DBA       BORO BUILDING  \
# 0       50106271                     Sour Mouse  Manhattan      110
# 1       50117820  Modello Bar - Barclays Center   Brooklyn      620
# 2       50141790                            Nan  Manhattan       30
# 3       50134862         Fine And Raw Chocolate   Brooklyn       70
# 4       50127238           The Deluxe Party Ktv     Queens     3420
# ...          ...                            ...        ...      ...
# 209784  50129459                      Blueberry   Brooklyn     1849
# 209785  41444866                  Pies-N-Thighs   Brooklyn      166
# 209786  50123805             Qk Restaurant Inc.     Queens     4626
# 209787  50056510        Ginbo's Hamburger House      Bronx      118
# 209788  41112524           Adrienne's Pizza Bar  Manhattan       54
#
#                      STREET  ZIPCODE       PHONE       CUISINE DESCRIPTION  \
# 0           Delancey Street    10002  6462567220                       NaN
# 1           Atlantic Avenue    11217  9174174384                       NaN
# 2        East   20th Street    10003  9176670036                       NaN
# 3              Scott Avenue    11237  6462440734                       NaN
# 4                 Linden Pl    11354  9172957843                       NaN
# ...                     ...      ...         ...                       ...
# 209784  Coney Island Avenue    11230  3473719836  Bakery Products/Desserts
# 209785  South    4th Street    11211  3475296090                  American
# 209786    Kissena Boulevard    11355  7189990806                   Chinese
# 209787   East  170th Street    10452  3479634644                Hamburgers
# 209788         Stone Street    10004  2122483838                   Italian
#
#        INSPECTION DATE                                           ACTION  \
# 0           01/01/1900                                              nan
# 1           01/01/1900                                              nan
# 2           01/01/1900                                              nan
# 3           01/01/1900                                              nan
# 4           01/01/1900                                              nan
# ...                ...                                              ...
# 209784      08/03/2023  Violations were cited in the following area(s).
# 209785      08/09/2023  Violations were cited in the following area(s).
# 209786      08/01/2022  Violations were cited in the following area(s).
# 209787      09/28/2022  Violations were cited in the following area(s).
# 209788      03/10/2022  Violations were cited in the following area(s).
#
#        VIOLATION CODE                              VIOLATION DESCRIPTION  \
# 0                 NaN                                                nan
# 1                 NaN                                                nan
# 2                 NaN                                                nan
# 3                 NaN                                                nan
# 4                 NaN                                                nan
# ...               ...                                                ...
# 209784            02A  Time/Temperature Control for Safety (TCS) food...
# 209785            04N  Filth flies or food/refuse/sewage associated w...
# 209786            06D  Food contact surface not properly washed, rins...
# 209787            08A  Establishment is not free of harborage or cond...
# 209788            04L  Evidence of mice or live mice present in facil...
#
#          CRITICAL FLAG  SCORE GRADE  GRADE DATE RECORD DATE  \
# 0       Not Applicable    NaN   NaN         NaN  12/01/2023
# 1       Not Applicable    NaN   NaN         NaN  12/01/2023
# 2       Not Applicable    NaN   NaN         NaN  12/01/2023
# 3       Not Applicable    NaN   NaN         NaN  12/01/2023
# 4       Not Applicable    NaN   NaN         NaN  12/01/2023
# ...                ...    ...   ...         ...         ...
# 209784        Critical   50.0   NaN         NaN  12/01/2023
# 209785        Critical   18.0     B  08/09/2023  12/01/2023
# 209786        Critical   29.0     C  08/01/2022  12/01/2023
# 209787    Not Critical   21.0   NaN         NaN  12/01/2023
# 209788        Critical   21.0   NaN         NaN  12/01/2023
#
#                                  INSPECTION TYPE   Latitude  Longitude  \
# 0                                            NaN  40.718640 -73.988481
# 1                                            NaN  40.683447 -73.975691
# 2                                            NaN  40.738929 -73.989221
# 3                                            NaN  40.709853 -73.922706
# 4                                            NaN  40.766275 -73.831338
# ...                                          ...        ...        ...
# 209784     Cycle Inspection / Initial Inspection  40.611980 -73.962744
# 209785          Cycle Inspection / Re-inspection  40.711289 -73.961300
# 209786  Pre-permit (Operational) / Re-inspection  40.750040 -73.818520
# 209787  Cycle Inspection / Compliance Inspection  40.839304 -73.915334
# 209788     Cycle Inspection / Initial Inspection  40.704403 -74.010211
#
#         Community Board  Council District  Census Tract        BIN  \
# 0                 103.0               1.0        1800.0  1087565.0
# 1                 302.0              35.0       12902.0  3398156.0
# 2                 105.0               2.0        5200.0  1016181.0
# 3                 301.0              34.0       44900.0  3070597.0
# 4                 407.0              20.0       86900.0  4112007.0
# ...                 ...               ...           ...        ...
# 209784            314.0              48.0       54200.0  3181708.0
# 209785            301.0              34.0       52300.0  3063458.0
# 209786            407.0              20.0       84500.0  4314742.0
# 209787            204.0              16.0       22102.0  2008084.0
# 209788            101.0               1.0         900.0  1088620.0
#
#                  BBL                                         NTA  \
# 0       1.004100e+09                                   Chinatown
# 1       3.011180e+09                          Park Slope-Gowanus
# 2       1.008480e+09  Hudson Yards-Chelsea-Flatiron-Union Square
# 3       3.029900e+09                           East Williamsburg
# 4       4.049500e+09                                    Flushing
# ...              ...                                         ...
# 209784  3.067580e+09                                     Midwood
# 209785  3.024460e+09                       North Side-South Side
# 209786  4.051490e+09                                    Flushing
# 209787  2.028420e+09                              West Concourse
# 209788  1.000298e+09           Battery Park City-Lower Manhattan
#
#         Location Point1                        Business Address
# 0                   NaN      110 Delancey Street, Manhattan, NY
# 1                   NaN       620 Atlantic Avenue, Brooklyn, NY
# 2                   NaN    30 East   20th Street, Manhattan, NY
# 3                   NaN           70 Scott Avenue, Brooklyn, NY
# 4                   NaN              3420 Linden Pl, Queens, NY
# ...                 ...                                     ...
# 209784              NaN  1849 Coney Island Avenue, Brooklyn, NY
# 209785              NaN   166 South    4th Street, Brooklyn, NY
# 209786              NaN      4626 Kissena Boulevard, Queens, NY
# 209787              NaN       118 East  170th Street, Bronx, NY
# 209788              NaN          54 Stone Street, Manhattan, NY
#
# [209772 rows x 28 columns]

# %%
dohmh_df.to_csv('cleaned_dohmh.csv', index=False)
