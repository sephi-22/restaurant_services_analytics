# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv("./data_csvs/currentOpenInspections.csv")

# %%
df1
# Out:
#          Borough             RestaurantName SeatingChoice  \
# 0      Manhattan                Oscar Wilde          both
# 1      Manhattan        LA RUBIA RESTAURANT          both
# 2      Manhattan               Thai Sliders      sidewalk
# 3       Brooklyn                      Otway          both
# 4       Brooklyn  WILLIAMSBURG THAI CUISINE          both
# ...          ...                        ...           ...
# 79198   Brooklyn                Sunshine Co          both
# 79199  Manhattan                  MOUSTACHE      sidewalk
# 79200   Brooklyn                Mekelburg's          both
# 79201   Brooklyn         Sunday In Brooklyn          both
# 79202   Brooklyn                      Otway          both
#
#                       LegalBusinessName     BusinessAddress  \
# 0                    Camelot Castle LLC    45  West 27th st
# 1               LA RUBIA RESTAURANT INC       3517 BROADWAY
# 2                        Silom Thai Inc       150   8th Ave
# ...

# %%
df1['AgencyCode'].value_counts()
# Out:
# DOT     62085
# DOB      3212
# DEP      1299
# FDNY      301
# DSNY      185
# CSM        85
# DDC        47
# DCAS       26
# Name: AgencyCode, dtype: int64

# %%
df1['SeatingChoice'].value_counts()
# Out:
# both           63973
# sidewalk        8425
# roadway         6791
# openstreets       14
# Name: SeatingChoice, dtype: int64

# %%
df1['SkippedReason'].value_counts()
# Out:
# No Seating               15723
# Sidewalk Seating Only     3619
# Open Street Location       339
# On Private Property        185
# Name: SkippedReason, dtype: int64

# %%
df1['Borough'].value_counts()
# Out:
# Manhattan        39512
# Brooklyn         20346
# Queens           14504
# Bronx             4396
# Staten Island      445
# Name: Borough, dtype: int64

# %%
df1['Postcode'].value_counts()
# Out:
# 10003    3298
# 10012    2605
# 10014    2602
# 10013    2317
# 10002    2186
#          ...
# 30608       1
# 10118       1
# 7607        1
# 11717       1
# 10106       1
# Name: Postcode, Length: 221, dtype: int64

# %%
df2 = pd.read_csv("./data_csvs/DOHMH_New_York_City_Restaurant_Inspection_Results_20231202.csv")

# %%
df2
# Out:
#            CAMIS                            DBA       BORO BUILDING  \
# 0       50106271                     SOUR MOUSE  Manhattan      110
# 1       50117820  MODELLO BAR - BARCLAYS CENTER   Brooklyn      620
# 2       50141790                            NaN  Manhattan       30
# 3       50134862         FINE AND RAW CHOCOLATE   Brooklyn       70
# 4       50127238           THE DELUXE PARTY KTV     Queens     3420
# ...          ...                            ...        ...      ...
# 209784  50129459                      BLUEBERRY   Brooklyn     1849
# 209785  41444866                  PIES-N-THIGHS   Brooklyn      166
# 209786  50123805             QK Restaurant Inc.     Queens     4626
# 209787  50056510        GINBO'S HAMBURGER HOUSE      Bronx      118
# 209788  41112524           ADRIENNE'S PIZZA BAR  Manhattan       54
#
#                      STREET  ZIPCODE       PHONE       CUISINE DESCRIPTION  \
# ...

# %%
df3 = pd.read_csv("./data_csvs/Open_Restaurant_Applications__Historic__20231202.csv")

# %%
df3
# Out:
#        objectid                                globalid  \
# 0         13610  {FD87ABAA-860E-4762-845D-8F0403D0246B}
# 1          5900  {3B07E4C0-07B7-4079-8333-64446CC3EE03}
# 2         13018  {137C575D-DC14-4F9D-83D9-A3FFE513B3B8}
# 3         11630  {15270732-2A78-4C24-89DD-BE8DD916F115}
# 4         13137  {EF9C8173-91D1-496E-8BD4-B02BEADC2A21}
# ...         ...                                     ...
# 14423      9799  {108C6784-54DB-480B-8627-CF0495D27A0E}
# 14424      8215  {7B8EC275-D470-4106-819E-03FC0E1F9717}
# 14425      2895  {476f88d2-d3e8-4e83-8686-8bac2f752cf5}
# 14426       607    ff0d04ef-1d9a-47d6-8f20-8bdbdbce2792
# 14427      6641  {9DBBF87C-AE3D-4487-81A4-30E44806614F}
#
#       Seating Interest (Sidewalk/Roadway/Both)            Restaurant Name  \
# 0                                      roadway               MADAME BONTE
# 1                                     sidewalk             Seasoned Vegan
# ...
