# %%
import pandas as pd
import numpy as np

# %%
scraped_df = pd.read_csv("yellowpages_newyork.csv")

# %%
scraped_df
# Out:
#       Restaurant ID                   Name  \
# 0                 1      EJ's Luncheonette
# 1                 2          Route 66 Cafe
# 2                 3     The Sea Fire Grill
# 3                 4                   Bobo
# 4                 5         Koi Restaurant
# ...             ...                    ...
# 2995           2996                Cafe 11
# 2996           2997  Saketumi Asian Bistro
# 2997           2998              Canaletto
# 2998           2999                 Julius
# 2999           3000       Professor Thom's
#
#                                      Type of Restaurant  Trip Advisor Rating  \
# 0     ['Restaurants', 'American Restaurants', 'Cater...                  4.0
# 1     ['Restaurants', 'American Restaurants', 'Coffe...                  4.0
# 2        ['Restaurants', 'Seafood Restaurants', 'Bars']                  4.5
# 3     ['Restaurants', 'Continental Restaurants', 'Ba...                  4.0
# ...

# %%
ahistoric_df = pd.read_csv("./data_csvs/Open_Restaurant_Applications__Historic__20231202.csv")

# %%
ahistoric_df
# Out:
#        objectid                                globalid  \
# 0         13610  {FD87ABAA-860E-4762-845D-8F0403D0246B}
# 1          5900  {3B07E4C0-07B7-4079-8333-64446CC3EE03}
# 2         13018  {137C575D-DC14-4F9D-83D9-A3FFE513B3B8}
# 3         11630  {15270732-2A78-4C24-89DD-BE8DD916F115}
# 4         13137  {EF9C8173-91D1-496E-8BD4-B02BEADC2A21}
# ...         ...                                     ...
# 14423      9799  {108C6784-54DB-480B-8627-CF0495D27A0E}
# 14424      8215  {7B8EC275-D470-4106-819E-03FC0E1F9717}
# 14425      2895  {476f88d2-d3e8-4e83-8686-8bac2f752cf5}
# 14426       607    ff0d04ef-1d9a-47d6-8f20-8bdbdbce2792
# 14427      6641  {9DBBF87C-AE3D-4487-81A4-30E44806614F}
#
#       Seating Interest (Sidewalk/Roadway/Both)            Restaurant Name  \
# 0                                      roadway               MADAME BONTE
# 1                                     sidewalk             Seasoned Vegan
# ...

# %%
ahistoric_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14428 entries, 0 to 14427
# Data columns (total 35 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   objectid                                  14428 non-null  int64
#  1   globalid                                  14428 non-null  object
#  2   Seating Interest (Sidewalk/Roadway/Both)  14428 non-null  object
#  3   Restaurant Name                           14427 non-null  object
#  4   Legal Business Name                       14427 non-null  object
#  5   Doing Business As (DBA)                   14416 non-null  object
#  6   Building Number                           12776 non-null  object
#  7   Street                                    14428 non-null  object
#  8   Borough                                   14428 non-null  object
#  9   Postcode                                  14428 non-null  int64
# ...

# %%
inspections_df = pd.read_csv("./data_csvs/currentOpenInspections.csv")

# %%
inspections_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79203 entries, 0 to 79202
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Borough                 79203 non-null  object
#  1   RestaurantName          79195 non-null  object
#  2   SeatingChoice           79203 non-null  object
#  3   LegalBusinessName       79202 non-null  object
#  4   BusinessAddress         79203 non-null  object
#  5   RestaurantInspectionID  79203 non-null  int64
#  6   IsSidewayCompliant      0 non-null      float64
#  7   IsRoadwayCompliant      79203 non-null  object
#  8   SkippedReason           19866 non-null  object
#  9   InspectedOn             79203 non-null  object
#  10  AgencyCode              67240 non-null  object
#  11  Postcode                79203 non-null  int64
#  12  Latitude                71320 non-null  float64
#  13  Longitude               71320 non-null  float64
# ...

# %%
health_df = pd.read_csv("./data_csvs/DOHMH_New_York_City_Restaurant_Inspection_Results_20231202.csv")

# %%
health_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209789 entries, 0 to 209788
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   CAMIS                  209789 non-null  int64
#  1   DBA                    209165 non-null  object
#  2   BORO                   209789 non-null  object
#  3   BUILDING               209481 non-null  object
#  4   STREET                 209783 non-null  object
#  5   ZIPCODE                207093 non-null  float64
#  6   PHONE                  209781 non-null  object
#  7   CUISINE DESCRIPTION    207365 non-null  object
#  8   INSPECTION DATE        209789 non-null  object
#  9   ACTION                 207365 non-null  object
#  10  VIOLATION CODE         206208 non-null  object
#  11  VIOLATION DESCRIPTION  206208 non-null  object
#  12  CRITICAL FLAG          209789 non-null  object
#  13  SCORE                  199793 non-null  float64
# ...

# %%
health_df['PHONE']
# Out:
# 0         6462567220
# 1         9174174384
# 2         9176670036
# 3         6462440734
# 4         9172957843
#              ...
# 209784    3473719836
# 209785    3475296090
# 209786    7189990806
# 209787    3479634644
# 209788    2122483838
# Name: PHONE, Length: 209789, dtype: object
